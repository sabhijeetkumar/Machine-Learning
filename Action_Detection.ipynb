# %%
pip install tensorflow-macos==2.5.0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-macos==2.5.0 (from versions: 2.12.0, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Users/abhijeetkumar/anaconda3/bin/python -m pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow-macos==2.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Requirement already satisfied: pyttsx3 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (2.98)
# Requirement already satisfied: pyobjc>=2.4 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-core==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AddressBook==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ApplicationServices==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Automator==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CFNetwork==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Cocoa==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreAudio==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreAudioKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreData==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreMIDI==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreServices==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreText==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DiscRecording==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DiscRecordingUI==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DiskArbitration==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DVDPlayback==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ExceptionHandling==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-InstallerPlugins==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-IOBluetooth==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-IOBluetoothUI==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LatentSemanticMapping==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LaunchServices==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-OSAKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PreferencePanes==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Quartz==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ScreenSaver==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Security==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SecurityFoundation==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SecurityInterface==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SearchKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SyncServices==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SystemConfiguration==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-WebKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AppleScriptObjC==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreLocation==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreWLAN==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ImageCaptureCore==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-IOSurface==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-NetFS==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-OpenDirectory==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ServiceManagement==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-iTunesLibrary==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AVFoundation==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreMedia==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreMediaIO==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-StoreKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SceneKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-libdispatch==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-libxpc==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AudioVideoBridging==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Accounts==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-EventKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-GameCenter==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Social==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-GameKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-VideoToolbox==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AVKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-GameController==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MapKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MediaAccessibility==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MediaLibrary==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MediaToolbox==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SpriteKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CloudKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreBluetooth==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CryptoTokenKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-FinderSync==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthentication==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MultipeerConnectivity==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-NotificationCenter==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Contacts==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ContactsUI==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Metal==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetalKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ModelIO==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-NetworkExtension==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Photos==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PhotosUI==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-GameplayKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Intents==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MediaPlayer==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SafariServices==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ColorSync==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreML==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreSpotlight==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ExternalAccessory==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShaders==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Vision==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AdSupport==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-BusinessChat==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-NaturalLanguage==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Network==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-UserNotifications==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-VideoSubscriberAccount==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AuthenticationServices==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AutomaticAssessmentConfiguration==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreHaptics==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CoreMotion==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DeviceCheck==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ExecutionPolicy==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-FileProvider==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-FileProviderUI==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LinkPresentation==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-OSLog==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PencilKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PushKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-QuickLookThumbnailing==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Speech==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SoundAnalysis==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SystemExtensions==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Accessibility==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AdServices==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AppTrackingTransparency==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CallKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ClassKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-KernelManagement==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetalPerformanceShadersGraph==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MLCompute==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PassKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ReplayKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ScreenTime==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-UniformTypeIdentifiers==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-UserNotificationsUI==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Virtualization==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DataDetection==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-IntentsUI==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-LocalAuthenticationEmbeddedUI==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MailKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetricKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-PHASE==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ShazamKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ScreenCaptureKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-AVRouting==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-BackgroundAssets==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ExtensionKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-HealthKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-MetalFX==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SafetyKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYouCore==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SharedWithYou==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ThreadNetwork==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Cinematic==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-SensitiveContentAnalysis==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Symbols==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-BrowserEngineKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-CalendarStore==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-Collaboration==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-DictionaryServices==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-FSEvents==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-InputMethodKit==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-InstantMessage==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
# Requirement already satisfied: pyobjc-framework-ScriptingBridge==10.3.1 in /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages (from pyobjc>=2.4->pyttsx3) (10.3.1)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Users/abhijeetkumar/anaconda3/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow==2.4.1
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.4.1 (from versions: 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Users/abhijeetkumar/anaconda3/bin/python -m pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow==2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow==2.4.1 opencv-python mediapipe scikit-learn matplotlib
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.4.1 (from versions: 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0, 2.15.1, 2.16.0rc0, 2.16.1, 2.16.2, 2.17.0rc0, 2.17.0rc1, 2.17.0, 2.17.1, 2.18.0rc0, 2.18.0rc1, 2.18.0rc2, 2.18.0)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Users/abhijeetkumar/anaconda3/bin/python -m pip install --upgrade pip
# ERROR: No matching distribution found for tensorflow==2.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import os
from matplotlib import pyplot as plt
import time
import mediapipe as mp
import math

# %%
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # COLOR CONVERSION BGR 2 RGB
    image.flags.writeable = False                  # Image is no longer writeable
    results = model.process(image)                 # Make prediction
    image.flags.writeable = True                   # Image is now writeable 
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR) # COLOR COVERSION RGB 2 BGR
    return image, results

# %%
def draw_landmarks(image, results):
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS) # Draw face connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS) # Draw pose connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS) # Draw right hand connections

# %%
def draw_styled_landmarks(image, results):
    # Draw face connections
    mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACE_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1), 
                             mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                             ) 
    # Draw pose connections
    mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                             mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                             ) 
    # Draw left hand connections
    mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                             ) 
    # Draw right hand connections  
    mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS, 
                             mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4), 
                             mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                             )

# %%
import cv2
import mediapipe as mp
import math

mp_holistic = mp.solutions.holistic
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

def mediapipe_detection(image, holistic_model, face_model):
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    holistic_results = holistic_model.process(image_rgb)
    
    face_results = face_model.process(image_rgb)
    
    image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)
    
    return image, holistic_results, face_results

def draw_styled_landmarks(image, holistic_results, face_results):
  
    if face_results.detections:
        for detection in face_results.detections:
            mp_drawing.draw_detection(image, detection,
                                      mp_drawing.DrawingSpec(color=(80,110,10), thickness=2, circle_radius=2),
                                      mp_drawing.DrawingSpec(color=(255,0,0), thickness=2))

    if holistic_results.face_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
            mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
            mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
        )
    
    if holistic_results.pose_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
        )
    
    if holistic_results.left_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
        )
    
    if holistic_results.right_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
        )

def calculate_distance(landmark1, landmark2, image_width, image_height):
    x1, y1 = landmark1.x * image_width, landmark1.y * image_height
    x2, y2 = landmark2.x * image_width, landmark2.y * image_height
    return math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)

cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic, \
     mp_face_detection.FaceDetection(min_detection_confidence=0.5) as face_detection:

    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            break

        image_height, image_width, _ = frame.shape

        image, holistic_results, face_results = mediapipe_detection(frame, holistic, face_detection)

        left_hand_text = "Left Hand: Not Detected"
        right_hand_text = "Right Hand: Not Detected"
        
        if holistic_results.left_hand_landmarks:
            landmarks = holistic_results.left_hand_landmarks.landmark
            
            index_finger_length_left = calculate_distance(landmarks[5], landmarks[8], image_width, image_height)
            left_hand_text = f"Left Hand Index Finger Length: {index_finger_length_left:.2f} pixels"
        
        if holistic_results.right_hand_landmarks:
            landmarks = holistic_results.right_hand_landmarks.landmark
            
            index_finger_length_right = calculate_distance(landmarks[5], landmarks[8], image_width, image_height)
            right_hand_text = f"Right Hand Index Finger Length: {index_finger_length_right:.2f} pixels"

        draw_styled_landmarks(image, holistic_results, face_results)

        cv2.putText(image, left_hand_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
        cv2.putText(image, right_hand_text, (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1730436931.211097   83698 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# I0000 00:00:1730436931.217156   83698 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1730436931.239094   84445 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436931.293789   84438 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436931.301415   84439 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436931.302690   84439 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436931.302779   84437 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436931.303079   84436 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436931.305784   84439 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436931.309753   84437 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436931.309883   84436 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /Users/abhijeetkumar/anaconda3/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# 2024-11-01 10:25:31.864 python[4815:83698] +[IMKClient subclass]: chose IMKClient_Legacy
# 2024-11-01 10:25:31.864 python[4815:83698] +[IMKInputSession subclass]: chose IMKInputSession_Legacy

# %% [markdown]
# with the Speech

# %%
import cv2
import mediapipe as mp
import math
import pyttsx3

# Initialize MediaPipe Holistic and Face Detection modules
mp_holistic = mp.solutions.holistic
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Function to detect and process image landmarks
def mediapipe_detection(image, holistic_model, face_model):
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    holistic_results = holistic_model.process(image_rgb)
    
    face_results = face_model.process(image_rgb)
    
    image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)
    
    return image, holistic_results, face_results

# Function to draw landmarks on the image
def draw_styled_landmarks(image, holistic_results, face_results):
    if face_results.detections:
        for detection in face_results.detections:
            mp_drawing.draw_detection(image, detection,
                                      mp_drawing.DrawingSpec(color=(80,110,10), thickness=2, circle_radius=2),
                                      mp_drawing.DrawingSpec(color=(255,0,0), thickness=2))

    if holistic_results.face_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
            mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
            mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
        )
    
    if holistic_results.pose_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
        )
    
    if holistic_results.left_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
        )
    
    if holistic_results.right_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
        )

# Function to calculate Euclidean distance between two points
def calculate_distance(landmark1, landmark2, image_width, image_height):
    x1, y1 = landmark1.x * image_width, landmark1.y * image_height
    x2, y2 = landmark2.x * image_width, landmark2.y * image_height
    return math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)

cap = cv2.VideoCapture(0)

# Initialize the speech engine properties (optional: adjust voice, rate, volume)
engine.setProperty('rate', 150)
engine.setProperty('volume', 0.9)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic, \
     mp_face_detection.FaceDetection(min_detection_confidence=0.5) as face_detection:

    prev_left_hand_text = ""
    prev_right_hand_text = ""

    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            break

        image_height, image_width, _ = frame.shape

        image, holistic_results, face_results = mediapipe_detection(frame, holistic, face_detection)

        left_hand_text = "Left Hand: Not Detected"
        right_hand_text = "Right Hand: Not Detected"
        
        if holistic_results.left_hand_landmarks:
            landmarks = holistic_results.left_hand_landmarks.landmark
            index_finger_length_left = calculate_distance(landmarks[5], landmarks[8], image_width, image_height)
            left_hand_text = f"Left Hand Index Finger Length: {index_finger_length_left:.2f} pixels"
        
        if holistic_results.right_hand_landmarks:
            landmarks = holistic_results.right_hand_landmarks.landmark
            index_finger_length_right = calculate_distance(landmarks[5], landmarks[8], image_width, image_height)
            right_hand_text = f"Right Hand Index Finger Length: {index_finger_length_right:.2f} pixels"

        # Speak the left hand and right hand lengths if they have changed
        if left_hand_text != prev_left_hand_text:
            engine.say(left_hand_text)
            prev_left_hand_text = left_hand_text

        if right_hand_text != prev_right_hand_text:
            engine.say(right_hand_text)
            prev_right_hand_text = right_hand_text

        engine.runAndWait()  # Ensure that the speaking happens in the main loop

        draw_styled_landmarks(image, holistic_results, face_results)

        # Display the lengths on the OpenCV feed
        cv2.putText(image, left_hand_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
        cv2.putText(image, right_hand_text, (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# objc[4815]: class `NSKVONotifying_AVCaptureConnection' not linked into application
# objc[4815]: class `NSKVONotifying_AVCaptureSession' not linked into application
# objc[4815]: class `NSKVONotifying_AVCaptureVideoDataOutput' not linked into application
# objc[4815]: class `NSKVONotifying_AVCaptureInputPort' not linked into application
# objc[4815]: class `NSKVONotifying_AVCaptureDeviceInput' not linked into application
# I0000 00:00:1730436977.604717   83698 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# I0000 00:00:1730436977.607007   83698 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# W0000 00:00:1730436977.609614   85274 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436977.679560   85265 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436977.688013   85266 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436977.689436   85269 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436977.689452   85266 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436977.689846   85267 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436977.692596   85268 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436977.694376   85269 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1730436977.696594   85266 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
import pyttsx3

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Get the available voices
voices = engine.getProperty('voices')

# Print the available voices
for index, voice in enumerate(voices):
    print(f"Voice {index}: ID = {voice.id}, Name = {voice.name}, Gender = {voice.gender if hasattr(voice, 'gender') else 'N/A'}")
# Out:
# Voice 0: ID = com.apple.speech.synthesis.voice.Albert, Name = Albert, Gender = VoiceGenderNeuter
# Voice 1: ID = com.apple.voice.compact.it-IT.Alice, Name = Alice, Gender = VoiceGenderFemale
# Voice 2: ID = com.apple.voice.compact.sv-SE.Alva, Name = Alva, Gender = VoiceGenderFemale
# Voice 3: ID = com.apple.voice.compact.fr-CA.Amelie, Name = Amélie, Gender = VoiceGenderFemale
# Voice 4: ID = com.apple.voice.compact.ms-MY.Amira, Name = Amira, Gender = VoiceGenderFemale
# Voice 5: ID = com.apple.voice.compact.de-DE.Anna, Name = Anna, Gender = VoiceGenderFemale
# Voice 6: ID = com.apple.speech.synthesis.voice.BadNews, Name = Bad News, Gender = VoiceGenderNeuter
# Voice 7: ID = com.apple.speech.synthesis.voice.Bahh, Name = Bahh, Gender = VoiceGenderNeuter
# Voice 8: ID = com.apple.speech.synthesis.voice.Bells, Name = Bells, Gender = VoiceGenderNeuter
# Voice 9: ID = com.apple.speech.synthesis.voice.Boing, Name = Boing, Gender = VoiceGenderNeuter
# Voice 10: ID = com.apple.speech.synthesis.voice.Bubbles, Name = Bubbles, Gender = VoiceGenderNeuter
# Voice 11: ID = com.apple.voice.compact.he-IL.Carmit, Name = Carmit, Gender = VoiceGenderFemale
# Voice 12: ID = com.apple.speech.synthesis.voice.Cellos, Name = Cellos, Gender = VoiceGenderNeuter
# Voice 13: ID = com.apple.voice.compact.id-ID.Damayanti, Name = Damayanti, Gender = VoiceGenderFemale
# Voice 14: ID = com.apple.voice.compact.en-GB.Daniel, Name = Daniel, Gender = VoiceGenderMale
# Voice 15: ID = com.apple.voice.compact.bg-BG.Daria, Name = Daria, Gender = VoiceGenderFemale
# Voice 16: ID = com.apple.speech.synthesis.voice.Deranged, Name = Wobble, Gender = VoiceGenderNeuter
# Voice 17: ID = com.apple.eloquence.de-DE.Eddy, Name = Eddy (German (Germany)), Gender = VoiceGenderNeuter
# Voice 18: ID = com.apple.eloquence.en-GB.Eddy, Name = Eddy (English (UK)), Gender = VoiceGenderNeuter
# Voice 19: ID = com.apple.eloquence.en-US.Eddy, Name = Eddy (English (US)), Gender = VoiceGenderNeuter
# Voice 20: ID = com.apple.eloquence.es-ES.Eddy, Name = Eddy (Spanish (Spain)), Gender = VoiceGenderNeuter
# Voice 21: ID = com.apple.eloquence.es-MX.Eddy, Name = Eddy (Spanish (Mexico)), Gender = VoiceGenderNeuter
# Voice 22: ID = com.apple.eloquence.fi-FI.Eddy, Name = Eddy (Finnish (Finland)), Gender = VoiceGenderNeuter
# Voice 23: ID = com.apple.eloquence.fr-CA.Eddy, Name = Eddy (French (Canada)), Gender = VoiceGenderNeuter
# Voice 24: ID = com.apple.eloquence.fr-FR.Eddy, Name = Eddy (French (France)), Gender = VoiceGenderNeuter
# Voice 25: ID = com.apple.eloquence.it-IT.Eddy, Name = Eddy (Italian (Italy)), Gender = VoiceGenderNeuter
# Voice 26: ID = com.apple.eloquence.ja-JP.Eddy, Name = Eddy (Japanese (Japan)), Gender = VoiceGenderNeuter
# Voice 27: ID = com.apple.eloquence.ko-KR.Eddy, Name = Eddy (Korean (South Korea)), Gender = VoiceGenderNeuter
# Voice 28: ID = com.apple.eloquence.pt-BR.Eddy, Name = Eddy (Portuguese (Brazil)), Gender = VoiceGenderNeuter
# Voice 29: ID = com.apple.eloquence.zh-CN.Eddy, Name = Eddy (Chinese (China mainland)), Gender = VoiceGenderNeuter
# Voice 30: ID = com.apple.eloquence.zh-TW.Eddy, Name = Eddy (Chinese (Taiwan)), Gender = VoiceGenderNeuter
# Voice 31: ID = com.apple.voice.compact.nl-BE.Ellen, Name = Ellen, Gender = VoiceGenderFemale
# Voice 32: ID = com.apple.eloquence.de-DE.Flo, Name = Flo (German (Germany)), Gender = VoiceGenderNeuter
# Voice 33: ID = com.apple.eloquence.en-GB.Flo, Name = Flo (English (UK)), Gender = VoiceGenderNeuter
# Voice 34: ID = com.apple.eloquence.en-US.Flo, Name = Flo (English (US)), Gender = VoiceGenderNeuter
# Voice 35: ID = com.apple.eloquence.es-ES.Flo, Name = Flo (Spanish (Spain)), Gender = VoiceGenderNeuter
# Voice 36: ID = com.apple.eloquence.es-MX.Flo, Name = Flo (Spanish (Mexico)), Gender = VoiceGenderNeuter
# Voice 37: ID = com.apple.eloquence.fi-FI.Flo, Name = Flo (Finnish (Finland)), Gender = VoiceGenderNeuter
# Voice 38: ID = com.apple.eloquence.fr-CA.Flo, Name = Flo (French (Canada)), Gender = VoiceGenderNeuter
# Voice 39: ID = com.apple.eloquence.fr-FR.Flo, Name = Flo (French (France)), Gender = VoiceGenderNeuter
# Voice 40: ID = com.apple.eloquence.it-IT.Flo, Name = Flo (Italian (Italy)), Gender = VoiceGenderNeuter
# Voice 41: ID = com.apple.eloquence.ja-JP.Flo, Name = Flo (Japanese (Japan)), Gender = VoiceGenderNeuter
# Voice 42: ID = com.apple.eloquence.ko-KR.Flo, Name = Flo (Korean (South Korea)), Gender = VoiceGenderNeuter
# Voice 43: ID = com.apple.eloquence.pt-BR.Flo, Name = Flo (Portuguese (Brazil)), Gender = VoiceGenderNeuter
# Voice 44: ID = com.apple.eloquence.zh-CN.Flo, Name = Flo (Chinese (China mainland)), Gender = VoiceGenderNeuter
# Voice 45: ID = com.apple.eloquence.zh-TW.Flo, Name = Flo (Chinese (Taiwan)), Gender = VoiceGenderNeuter
# Voice 46: ID = com.apple.speech.synthesis.voice.Fred, Name = Fred, Gender = VoiceGenderMale
# Voice 47: ID = com.apple.speech.synthesis.voice.GoodNews, Name = Good News, Gender = VoiceGenderNeuter
# Voice 48: ID = com.apple.eloquence.de-DE.Grandma, Name = Grandma (German (Germany)), Gender = VoiceGenderNeuter
# Voice 49: ID = com.apple.eloquence.en-GB.Grandma, Name = Grandma (English (UK)), Gender = VoiceGenderNeuter
# Voice 50: ID = com.apple.eloquence.en-US.Grandma, Name = Grandma (English (US)), Gender = VoiceGenderNeuter
# Voice 51: ID = com.apple.eloquence.es-ES.Grandma, Name = Grandma (Spanish (Spain)), Gender = VoiceGenderNeuter
# Voice 52: ID = com.apple.eloquence.es-MX.Grandma, Name = Grandma (Spanish (Mexico)), Gender = VoiceGenderNeuter
# Voice 53: ID = com.apple.eloquence.fi-FI.Grandma, Name = Grandma (Finnish (Finland)), Gender = VoiceGenderNeuter
# Voice 54: ID = com.apple.eloquence.fr-CA.Grandma, Name = Grandma (French (Canada)), Gender = VoiceGenderNeuter
# Voice 55: ID = com.apple.eloquence.fr-FR.Grandma, Name = Grandma (French (France)), Gender = VoiceGenderNeuter
# Voice 56: ID = com.apple.eloquence.it-IT.Grandma, Name = Grandma (Italian (Italy)), Gender = VoiceGenderNeuter
# Voice 57: ID = com.apple.eloquence.ja-JP.Grandma, Name = Grandma (Japanese (Japan)), Gender = VoiceGenderNeuter
# Voice 58: ID = com.apple.eloquence.ko-KR.Grandma, Name = Grandma (Korean (South Korea)), Gender = VoiceGenderNeuter
# Voice 59: ID = com.apple.eloquence.pt-BR.Grandma, Name = Grandma (Portuguese (Brazil)), Gender = VoiceGenderNeuter
# Voice 60: ID = com.apple.eloquence.zh-CN.Grandma, Name = Grandma (Chinese (China mainland)), Gender = VoiceGenderNeuter
# Voice 61: ID = com.apple.eloquence.zh-TW.Grandma, Name = Grandma (Chinese (Taiwan)), Gender = VoiceGenderNeuter
# Voice 62: ID = com.apple.eloquence.de-DE.Grandpa, Name = Grandpa (German (Germany)), Gender = VoiceGenderNeuter
# Voice 63: ID = com.apple.eloquence.en-GB.Grandpa, Name = Grandpa (English (UK)), Gender = VoiceGenderNeuter
# Voice 64: ID = com.apple.eloquence.en-US.Grandpa, Name = Grandpa (English (US)), Gender = VoiceGenderNeuter
# Voice 65: ID = com.apple.eloquence.es-ES.Grandpa, Name = Grandpa (Spanish (Spain)), Gender = VoiceGenderNeuter
# Voice 66: ID = com.apple.eloquence.es-MX.Grandpa, Name = Grandpa (Spanish (Mexico)), Gender = VoiceGenderNeuter
# Voice 67: ID = com.apple.eloquence.fi-FI.Grandpa, Name = Grandpa (Finnish (Finland)), Gender = VoiceGenderNeuter
# Voice 68: ID = com.apple.eloquence.fr-CA.Grandpa, Name = Grandpa (French (Canada)), Gender = VoiceGenderNeuter
# Voice 69: ID = com.apple.eloquence.fr-FR.Grandpa, Name = Grandpa (French (France)), Gender = VoiceGenderNeuter
# Voice 70: ID = com.apple.eloquence.it-IT.Grandpa, Name = Grandpa (Italian (Italy)), Gender = VoiceGenderNeuter
# Voice 71: ID = com.apple.eloquence.ja-JP.Grandpa, Name = Grandpa (Japanese (Japan)), Gender = VoiceGenderNeuter
# Voice 72: ID = com.apple.eloquence.ko-KR.Grandpa, Name = Grandpa (Korean (South Korea)), Gender = VoiceGenderNeuter
# Voice 73: ID = com.apple.eloquence.pt-BR.Grandpa, Name = Grandpa (Portuguese (Brazil)), Gender = VoiceGenderNeuter
# Voice 74: ID = com.apple.eloquence.zh-CN.Grandpa, Name = Grandpa (Chinese (China mainland)), Gender = VoiceGenderNeuter
# Voice 75: ID = com.apple.eloquence.zh-TW.Grandpa, Name = Grandpa (Chinese (Taiwan)), Gender = VoiceGenderNeuter
# Voice 76: ID = com.apple.speech.synthesis.voice.Hysterical, Name = Jester, Gender = VoiceGenderNeuter
# Voice 77: ID = com.apple.voice.compact.ro-RO.Ioana, Name = Ioana, Gender = VoiceGenderFemale
# Voice 78: ID = com.apple.eloquence.fr-FR.Jacques, Name = Jacques, Gender = VoiceGenderNeuter
# Voice 79: ID = com.apple.voice.compact.pt-PT.Joana, Name = Joana, Gender = VoiceGenderFemale
# Voice 80: ID = com.apple.speech.synthesis.voice.Junior, Name = Junior, Gender = VoiceGenderNeuter
# Voice 81: ID = com.apple.voice.compact.th-TH.Kanya, Name = Kanya, Gender = VoiceGenderFemale
# Voice 82: ID = com.apple.voice.compact.en-AU.Karen, Name = Karen, Gender = VoiceGenderFemale
# Voice 83: ID = com.apple.speech.synthesis.voice.Kathy, Name = Kathy, Gender = VoiceGenderNeuter
# Voice 84: ID = com.apple.voice.compact.ja-JP.Kyoko, Name = Kyoko, Gender = VoiceGenderFemale
# Voice 85: ID = com.apple.voice.compact.hr-HR.Lana, Name = Lana, Gender = VoiceGenderFemale
# Voice 86: ID = com.apple.voice.compact.sk-SK.Laura, Name = Laura, Gender = VoiceGenderFemale
# Voice 87: ID = com.apple.voice.compact.hi-IN.Lekha, Name = Lekha, Gender = VoiceGenderFemale
# Voice 88: ID = com.apple.voice.compact.uk-UA.Lesya, Name = Lesya, Gender = VoiceGenderFemale
# Voice 89: ID = com.apple.voice.compact.vi-VN.Linh, Name = Linh, Gender = VoiceGenderFemale
# Voice 90: ID = com.apple.voice.compact.pt-BR.Luciana, Name = Luciana, Gender = VoiceGenderFemale
# Voice 91: ID = com.apple.voice.compact.ar-001.Maged, Name = Majed, Gender = VoiceGenderMale
# Voice 92: ID = com.apple.voice.compact.hu-HU.Mariska, Name = Tünde, Gender = VoiceGenderFemale
# Voice 93: ID = com.apple.voice.compact.zh-TW.Meijia, Name = Meijia, Gender = VoiceGenderFemale
# Voice 94: ID = com.apple.voice.compact.el-GR.Melina, Name = Melina, Gender = VoiceGenderFemale
# Voice 95: ID = com.apple.voice.compact.ru-RU.Milena, Name = Milena, Gender = VoiceGenderFemale
# Voice 96: ID = com.apple.voice.compact.en-IE.Moira, Name = Moira, Gender = VoiceGenderFemale
# Voice 97: ID = com.apple.voice.compact.es-ES.Monica, Name = Mónica, Gender = VoiceGenderFemale
# Voice 98: ID = com.apple.voice.compact.ca-ES.Montserrat, Name = Montse, Gender = VoiceGenderFemale
# Voice 99: ID = com.apple.voice.compact.nb-NO.Nora, Name = Nora, Gender = VoiceGenderFemale
# Voice 100: ID = com.apple.speech.synthesis.voice.Organ, Name = Organ, Gender = VoiceGenderNeuter
# Voice 101: ID = com.apple.voice.compact.es-MX.Paulina, Name = Paulina, Gender = VoiceGenderFemale
# Voice 102: ID = com.apple.speech.synthesis.voice.Princess, Name = Superstar, Gender = VoiceGenderNeuter
# Voice 103: ID = com.apple.speech.synthesis.voice.Ralph, Name = Ralph, Gender = VoiceGenderNeuter
# Voice 104: ID = com.apple.eloquence.de-DE.Reed, Name = Reed (German (Germany)), Gender = VoiceGenderNeuter
# Voice 105: ID = com.apple.eloquence.en-GB.Reed, Name = Reed (English (UK)), Gender = VoiceGenderNeuter
# Voice 106: ID = com.apple.eloquence.en-US.Reed, Name = Reed (English (US)), Gender = VoiceGenderNeuter
# Voice 107: ID = com.apple.eloquence.es-ES.Reed, Name = Reed (Spanish (Spain)), Gender = VoiceGenderNeuter
# Voice 108: ID = com.apple.eloquence.es-MX.Reed, Name = Reed (Spanish (Mexico)), Gender = VoiceGenderNeuter
# Voice 109: ID = com.apple.eloquence.fi-FI.Reed, Name = Reed (Finnish (Finland)), Gender = VoiceGenderNeuter
# Voice 110: ID = com.apple.eloquence.fr-CA.Reed, Name = Reed (French (Canada)), Gender = VoiceGenderNeuter
# Voice 111: ID = com.apple.eloquence.it-IT.Reed, Name = Reed (Italian (Italy)), Gender = VoiceGenderNeuter
# Voice 112: ID = com.apple.eloquence.ja-JP.Reed, Name = Reed (Japanese (Japan)), Gender = VoiceGenderNeuter
# Voice 113: ID = com.apple.eloquence.ko-KR.Reed, Name = Reed (Korean (South Korea)), Gender = VoiceGenderNeuter
# Voice 114: ID = com.apple.eloquence.pt-BR.Reed, Name = Reed (Portuguese (Brazil)), Gender = VoiceGenderNeuter
# Voice 115: ID = com.apple.eloquence.zh-CN.Reed, Name = Reed (Chinese (China mainland)), Gender = VoiceGenderNeuter
# Voice 116: ID = com.apple.eloquence.zh-TW.Reed, Name = Reed (Chinese (Taiwan)), Gender = VoiceGenderNeuter
# Voice 117: ID = com.apple.voice.compact.en-IN.Rishi, Name = Rishi, Gender = VoiceGenderMale
# Voice 118: ID = com.apple.eloquence.de-DE.Rocko, Name = Rocko (German (Germany)), Gender = VoiceGenderNeuter
# Voice 119: ID = com.apple.eloquence.en-GB.Rocko, Name = Rocko (English (UK)), Gender = VoiceGenderNeuter
# Voice 120: ID = com.apple.eloquence.en-US.Rocko, Name = Rocko (English (US)), Gender = VoiceGenderNeuter
# Voice 121: ID = com.apple.eloquence.es-ES.Rocko, Name = Rocko (Spanish (Spain)), Gender = VoiceGenderNeuter
# Voice 122: ID = com.apple.eloquence.es-MX.Rocko, Name = Rocko (Spanish (Mexico)), Gender = VoiceGenderNeuter
# Voice 123: ID = com.apple.eloquence.fi-FI.Rocko, Name = Rocko (Finnish (Finland)), Gender = VoiceGenderNeuter
# Voice 124: ID = com.apple.eloquence.fr-CA.Rocko, Name = Rocko (French (Canada)), Gender = VoiceGenderNeuter
# Voice 125: ID = com.apple.eloquence.fr-FR.Rocko, Name = Rocko (French (France)), Gender = VoiceGenderNeuter
# Voice 126: ID = com.apple.eloquence.it-IT.Rocko, Name = Rocko (Italian (Italy)), Gender = VoiceGenderNeuter
# Voice 127: ID = com.apple.eloquence.ja-JP.Rocko, Name = Rocko (Japanese (Japan)), Gender = VoiceGenderNeuter
# Voice 128: ID = com.apple.eloquence.ko-KR.Rocko, Name = Rocko (Korean (South Korea)), Gender = VoiceGenderNeuter
# Voice 129: ID = com.apple.eloquence.pt-BR.Rocko, Name = Rocko (Portuguese (Brazil)), Gender = VoiceGenderNeuter
# Voice 130: ID = com.apple.eloquence.zh-CN.Rocko, Name = Rocko (Chinese (China mainland)), Gender = VoiceGenderNeuter
# Voice 131: ID = com.apple.eloquence.zh-TW.Rocko, Name = Rocko (Chinese (Taiwan)), Gender = VoiceGenderNeuter
# Voice 132: ID = com.apple.voice.compact.en-US.Samantha, Name = Samantha, Gender = VoiceGenderFemale
# Voice 133: ID = com.apple.eloquence.de-DE.Sandy, Name = Sandy (German (Germany)), Gender = VoiceGenderNeuter
# Voice 134: ID = com.apple.eloquence.en-GB.Sandy, Name = Sandy (English (UK)), Gender = VoiceGenderNeuter
# Voice 135: ID = com.apple.eloquence.en-US.Sandy, Name = Sandy (English (US)), Gender = VoiceGenderNeuter
# Voice 136: ID = com.apple.eloquence.es-ES.Sandy, Name = Sandy (Spanish (Spain)), Gender = VoiceGenderNeuter
# Voice 137: ID = com.apple.eloquence.es-MX.Sandy, Name = Sandy (Spanish (Mexico)), Gender = VoiceGenderNeuter
# Voice 138: ID = com.apple.eloquence.fi-FI.Sandy, Name = Sandy (Finnish (Finland)), Gender = VoiceGenderNeuter
# Voice 139: ID = com.apple.eloquence.fr-CA.Sandy, Name = Sandy (French (Canada)), Gender = VoiceGenderNeuter
# Voice 140: ID = com.apple.eloquence.fr-FR.Sandy, Name = Sandy (French (France)), Gender = VoiceGenderNeuter
# Voice 141: ID = com.apple.eloquence.it-IT.Sandy, Name = Sandy (Italian (Italy)), Gender = VoiceGenderNeuter
# Voice 142: ID = com.apple.eloquence.ja-JP.Sandy, Name = Sandy (Japanese (Japan)), Gender = VoiceGenderNeuter
# Voice 143: ID = com.apple.eloquence.ko-KR.Sandy, Name = Sandy (Korean (South Korea)), Gender = VoiceGenderNeuter
# Voice 144: ID = com.apple.eloquence.pt-BR.Sandy, Name = Sandy (Portuguese (Brazil)), Gender = VoiceGenderNeuter
# Voice 145: ID = com.apple.eloquence.zh-CN.Sandy, Name = Sandy (Chinese (China mainland)), Gender = VoiceGenderNeuter
# Voice 146: ID = com.apple.eloquence.zh-TW.Sandy, Name = Sandy (Chinese (Taiwan)), Gender = VoiceGenderNeuter
# Voice 147: ID = com.apple.voice.compact.da-DK.Sara, Name = Sara, Gender = VoiceGenderFemale
# Voice 148: ID = com.apple.voice.compact.fi-FI.Satu, Name = Satu, Gender = VoiceGenderFemale
# Voice 149: ID = com.apple.eloquence.de-DE.Shelley, Name = Shelley (German (Germany)), Gender = VoiceGenderNeuter
# Voice 150: ID = com.apple.eloquence.en-GB.Shelley, Name = Shelley (English (UK)), Gender = VoiceGenderNeuter
# Voice 151: ID = com.apple.eloquence.en-US.Shelley, Name = Shelley (English (US)), Gender = VoiceGenderNeuter
# Voice 152: ID = com.apple.eloquence.es-ES.Shelley, Name = Shelley (Spanish (Spain)), Gender = VoiceGenderNeuter
# Voice 153: ID = com.apple.eloquence.es-MX.Shelley, Name = Shelley (Spanish (Mexico)), Gender = VoiceGenderNeuter
# Voice 154: ID = com.apple.eloquence.fi-FI.Shelley, Name = Shelley (Finnish (Finland)), Gender = VoiceGenderNeuter
# Voice 155: ID = com.apple.eloquence.fr-CA.Shelley, Name = Shelley (French (Canada)), Gender = VoiceGenderNeuter
# Voice 156: ID = com.apple.eloquence.fr-FR.Shelley, Name = Shelley (French (France)), Gender = VoiceGenderNeuter
# Voice 157: ID = com.apple.eloquence.it-IT.Shelley, Name = Shelley (Italian (Italy)), Gender = VoiceGenderNeuter
# Voice 158: ID = com.apple.eloquence.ja-JP.Shelley, Name = Shelley (Japanese (Japan)), Gender = VoiceGenderNeuter
# Voice 159: ID = com.apple.eloquence.ko-KR.Shelley, Name = Shelley (Korean (South Korea)), Gender = VoiceGenderNeuter
# Voice 160: ID = com.apple.eloquence.pt-BR.Shelley, Name = Shelley (Portuguese (Brazil)), Gender = VoiceGenderNeuter
# Voice 161: ID = com.apple.eloquence.zh-CN.Shelley, Name = Shelley (Chinese (China mainland)), Gender = VoiceGenderNeuter
# Voice 162: ID = com.apple.eloquence.zh-TW.Shelley, Name = Shelley (Chinese (Taiwan)), Gender = VoiceGenderNeuter
# Voice 163: ID = com.apple.voice.compact.zh-HK.Sinji, Name = Sinji, Gender = VoiceGenderFemale
# Voice 164: ID = com.apple.voice.compact.en-ZA.Tessa, Name = Tessa, Gender = VoiceGenderFemale
# Voice 165: ID = com.apple.voice.compact.fr-FR.Thomas, Name = Thomas, Gender = VoiceGenderMale
# Voice 166: ID = com.apple.voice.compact.sl-SI.Tina, Name = Tina, Gender = VoiceGenderFemale
# Voice 167: ID = com.apple.voice.compact.zh-CN.Tingting, Name = Tingting, Gender = VoiceGenderFemale
# Voice 168: ID = com.apple.speech.synthesis.voice.Trinoids, Name = Trinoids, Gender = VoiceGenderNeuter
# Voice 169: ID = com.apple.speech.synthesis.voice.Whisper, Name = Whisper, Gender = VoiceGenderNeuter
# Voice 170: ID = com.apple.voice.compact.nl-NL.Xander, Name = Xander, Gender = VoiceGenderMale
# Voice 171: ID = com.apple.voice.compact.tr-TR.Yelda, Name = Yelda, Gender = VoiceGenderFemale
# Voice 172: ID = com.apple.voice.compact.ko-KR.Yuna, Name = Yuna, Gender = VoiceGenderFemale
# Voice 173: ID = com.apple.speech.synthesis.voice.Zarvox, Name = Zarvox, Gender = VoiceGenderNeuter
# Voice 174: ID = com.apple.voice.compact.pl-PL.Zosia, Name = Zosia, Gender = VoiceGenderFemale
# Voice 175: ID = com.apple.voice.compact.cs-CZ.Zuzana, Name = Zuzana, Gender = VoiceGenderFemale

# %%
index_of_female_voice = 0 
engine.setProperty('voice', voices[index_of_female_voice].id)

# %%
import cv2
import mediapipe as mp
import math
import pyttsx3

# Initialize MediaPipe Holistic and Face Detection modules
mp_holistic = mp.solutions.holistic
mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

# Initialize the text-to-speech engine
engine = pyttsx3.init()

# Get the available voices
voices = engine.getProperty('voices')

# Print the available voices to identify the female voice
for index, voice in enumerate(voices):
    print(f"Voice {index}: ID = {voice.id}, Name = {voice.name}")

# Set the female voice (change this index based on your results)
index_of_female_voice = 0  # Update this based on the print output
engine.setProperty('voice', voices[index_of_female_voice].id)

# Function to detect and process image landmarks
def mediapipe_detection(image, holistic_model, face_model):
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    holistic_results = holistic_model.process(image_rgb)
    
    face_results = face_model.process(image_rgb)
    
    image = cv2.cvtColor(image_rgb, cv2.COLOR_RGB2BGR)
    
    return image, holistic_results, face_results

# Function to draw landmarks on the image
def draw_styled_landmarks(image, holistic_results, face_results):
    if face_results.detections:
        for detection in face_results.detections:
            mp_drawing.draw_detection(image, detection,
                                      mp_drawing.DrawingSpec(color=(80,110,10), thickness=2, circle_radius=2),
                                      mp_drawing.DrawingSpec(color=(255,0,0), thickness=2))

    if holistic_results.face_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.face_landmarks, mp_holistic.FACEMESH_TESSELATION, 
            mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
            mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
        )
    
    if holistic_results.pose_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
        )
    
    if holistic_results.left_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
        )
    
    if holistic_results.right_hand_landmarks:
        mp_drawing.draw_landmarks(
            image, holistic_results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
            mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
        )

# Function to calculate Euclidean distance between two points
def calculate_distance(landmark1, landmark2, image_width, image_height):
    x1, y1 = landmark1.x * image_width, landmark1.y * image_height
    x2, y2 = landmark2.x * image_width, landmark2.y * image_height
    return math.sqrt((x2 - x1) ** 2 + (y2 - y1) ** 2)

cap = cv2.VideoCapture(0)

# Initialize the speech engine properties (optional: adjust rate, volume)
engine.setProperty('rate', 150)
engine.setProperty('volume', 0.9)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic, \
     mp_face_detection.FaceDetection(min_detection_confidence=0.5) as face_detection:

    prev_left_hand_text = ""
    prev_right_hand_text = ""

    while cap.isOpened():
        ret, frame = cap.read()

        if not ret:
            break

        image_height, image_width, _ = frame.shape

        image, holistic_results, face_results = mediapipe_detection(frame, holistic, face_detection)

        left_hand_text = "Left Hand: Not Detected"
        right_hand_text = "Right Hand: Not Detected"
        
        if holistic_results.left_hand_landmarks:
            landmarks = holistic_results.left_hand_landmarks.landmark
            index_finger_length_left = calculate_distance(landmarks[5], landmarks[8], image_width, image_height)
            left_hand_text = f"Left Hand Index Finger Length: {index_finger_length_left:.2f} pixels"
        
        if holistic_results.right_hand_landmarks:
            landmarks = holistic_results.right_hand_landmarks.landmark
            index_finger_length_right = calculate_distance(landmarks[5], landmarks[8], image_width, image_height)
            right_hand_text = f"Right Hand Index Finger Length: {index_finger_length_right:.2f} pixels"

        
        if left_hand_text != prev_left_hand_text:
            engine.say(left_hand_text)
            prev_left_hand_text = left_hand_text

        if right_hand_text != prev_right_hand_text:
            engine.say(right_hand_text)
            prev_right_hand_text = right_hand_text

        engine.runAndWait()

        draw_styled_landmarks(image, holistic_results, face_results)

        cv2.putText(image, left_hand_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)
        cv2.putText(image, right_hand_text, (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

        cv2.imshow('OpenCV Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Voice 0: ID = com.apple.speech.synthesis.voice.Albert, Name = Albert
# Voice 1: ID = com.apple.voice.compact.it-IT.Alice, Name = Alice
# Voice 2: ID = com.apple.voice.compact.sv-SE.Alva, Name = Alva
# Voice 3: ID = com.apple.voice.compact.fr-CA.Amelie, Name = Amélie
# Voice 4: ID = com.apple.voice.compact.ms-MY.Amira, Name = Amira
# Voice 5: ID = com.apple.voice.compact.de-DE.Anna, Name = Anna
# Voice 6: ID = com.apple.speech.synthesis.voice.BadNews, Name = Bad News
# Voice 7: ID = com.apple.speech.synthesis.voice.Bahh, Name = Bahh
# Voice 8: ID = com.apple.speech.synthesis.voice.Bells, Name = Bells
# Voice 9: ID = com.apple.speech.synthesis.voice.Boing, Name = Boing
# Voice 10: ID = com.apple.speech.synthesis.voice.Bubbles, Name = Bubbles
# Voice 11: ID = com.apple.voice.compact.he-IL.Carmit, Name = Carmit
# Voice 12: ID = com.apple.speech.synthesis.voice.Cellos, Name = Cellos
# Voice 13: ID = com.apple.voice.compact.id-ID.Damayanti, Name = Damayanti
# Voice 14: ID = com.apple.voice.compact.en-GB.Daniel, Name = Daniel
# Voice 15: ID = com.apple.voice.compact.bg-BG.Daria, Name = Daria
# Voice 16: ID = com.apple.speech.synthesis.voice.Deranged, Name = Wobble
# Voice 17: ID = com.apple.eloquence.de-DE.Eddy, Name = Eddy (German (Germany))
# Voice 18: ID = com.apple.eloquence.en-GB.Eddy, Name = Eddy (English (UK))
# Voice 19: ID = com.apple.eloquence.en-US.Eddy, Name = Eddy (English (US))
# Voice 20: ID = com.apple.eloquence.es-ES.Eddy, Name = Eddy (Spanish (Spain))
# Voice 21: ID = com.apple.eloquence.es-MX.Eddy, Name = Eddy (Spanish (Mexico))
# Voice 22: ID = com.apple.eloquence.fi-FI.Eddy, Name = Eddy (Finnish (Finland))
# Voice 23: ID = com.apple.eloquence.fr-CA.Eddy, Name = Eddy (French (Canada))
# Voice 24: ID = com.apple.eloquence.fr-FR.Eddy, Name = Eddy (French (France))
# Voice 25: ID = com.apple.eloquence.it-IT.Eddy, Name = Eddy (Italian (Italy))
# Voice 26: ID = com.apple.eloquence.ja-JP.Eddy, Name = Eddy (Japanese (Japan))
# Voice 27: ID = com.apple.eloquence.ko-KR.Eddy, Name = Eddy (Korean (South Korea))
# Voice 28: ID = com.apple.eloquence.pt-BR.Eddy, Name = Eddy (Portuguese (Brazil))
# Voice 29: ID = com.apple.eloquence.zh-CN.Eddy, Name = Eddy (Chinese (China mainland))
# Voice 30: ID = com.apple.eloquence.zh-TW.Eddy, Name = Eddy (Chinese (Taiwan))
# Voice 31: ID = com.apple.voice.compact.nl-BE.Ellen, Name = Ellen
# Voice 32: ID = com.apple.eloquence.de-DE.Flo, Name = Flo (German (Germany))
# Voice 33: ID = com.apple.eloquence.en-GB.Flo, Name = Flo (English (UK))
# Voice 34: ID = com.apple.eloquence.en-US.Flo, Name = Flo (English (US))
# Voice 35: ID = com.apple.eloquence.es-ES.Flo, Name = Flo (Spanish (Spain))
# Voice 36: ID = com.apple.eloquence.es-MX.Flo, Name = Flo (Spanish (Mexico))
# Voice 37: ID = com.apple.eloquence.fi-FI.Flo, Name = Flo (Finnish (Finland))
# Voice 38: ID = com.apple.eloquence.fr-CA.Flo, Name = Flo (French (Canada))
# Voice 39: ID = com.apple.eloquence.fr-FR.Flo, Name = Flo (French (France))
# Voice 40: ID = com.apple.eloquence.it-IT.Flo, Name = Flo (Italian (Italy))
# Voice 41: ID = com.apple.eloquence.ja-JP.Flo, Name = Flo (Japanese (Japan))
# Voice 42: ID = com.apple.eloquence.ko-KR.Flo, Name = Flo (Korean (South Korea))
# Voice 43: ID = com.apple.eloquence.pt-BR.Flo, Name = Flo (Portuguese (Brazil))
# Voice 44: ID = com.apple.eloquence.zh-CN.Flo, Name = Flo (Chinese (China mainland))
# Voice 45: ID = com.apple.eloquence.zh-TW.Flo, Name = Flo (Chinese (Taiwan))
# Voice 46: ID = com.apple.speech.synthesis.voice.Fred, Name = Fred
# Voice 47: ID = com.apple.speech.synthesis.voice.GoodNews, Name = Good News
# Voice 48: ID = com.apple.eloquence.de-DE.Grandma, Name = Grandma (German (Germany))
# Voice 49: ID = com.apple.eloquence.en-GB.Grandma, Name = Grandma (English (UK))
# Voice 50: ID = com.apple.eloquence.en-US.Grandma, Name = Grandma (English (US))
# Voice 51: ID = com.apple.eloquence.es-ES.Grandma, Name = Grandma (Spanish (Spain))
# Voice 52: ID = com.apple.eloquence.es-MX.Grandma, Name = Grandma (Spanish (Mexico))
# Voice 53: ID = com.apple.eloquence.fi-FI.Grandma, Name = Grandma (Finnish (Finland))
# Voice 54: ID = com.apple.eloquence.fr-CA.Grandma, Name = Grandma (French (Canada))
# Voice 55: ID = com.apple.eloquence.fr-FR.Grandma, Name = Grandma (French (France))
# Voice 56: ID = com.apple.eloquence.it-IT.Grandma, Name = Grandma (Italian (Italy))
# Voice 57: ID = com.apple.eloquence.ja-JP.Grandma, Name = Grandma (Japanese (Japan))
# Voice 58: ID = com.apple.eloquence.ko-KR.Grandma, Name = Grandma (Korean (South Korea))
# Voice 59: ID = com.apple.eloquence.pt-BR.Grandma, Name = Grandma (Portuguese (Brazil))
# Voice 60: ID = com.apple.eloquence.zh-CN.Grandma, Name = Grandma (Chinese (China mainland))
# Voice 61: ID = com.apple.eloquence.zh-TW.Grandma, Name = Grandma (Chinese (Taiwan))
# Voice 62: ID = com.apple.eloquence.de-DE.Grandpa, Name = Grandpa (German (Germany))
# Voice 63: ID = com.apple.eloquence.en-GB.Grandpa, Name = Grandpa (English (UK))
# Voice 64: ID = com.apple.eloquence.en-US.Grandpa, Name = Grandpa (English (US))
# Voice 65: ID = com.apple.eloquence.es-ES.Grandpa, Name = Grandpa (Spanish (Spain))
# Voice 66: ID = com.apple.eloquence.es-MX.Grandpa, Name = Grandpa (Spanish (Mexico))
# Voice 67: ID = com.apple.eloquence.fi-FI.Grandpa, Name = Grandpa (Finnish (Finland))
# Voice 68: ID = com.apple.eloquence.fr-CA.Grandpa, Name = Grandpa (French (Canada))
# Voice 69: ID = com.apple.eloquence.fr-FR.Grandpa, Name = Grandpa (French (France))
# Voice 70: ID = com.apple.eloquence.it-IT.Grandpa, Name = Grandpa (Italian (Italy))
# Voice 71: ID = com.apple.eloquence.ja-JP.Grandpa, Name = Grandpa (Japanese (Japan))
# Voice 72: ID = com.apple.eloquence.ko-KR.Grandpa, Name = Grandpa (Korean (South Korea))
# Voice 73: ID = com.apple.eloquence.pt-BR.Grandpa, Name = Grandpa (Portuguese (Brazil))
# Voice 74: ID = com.apple.eloquence.zh-CN.Grandpa, Name = Grandpa (Chinese (China mainland))
# Voice 75: ID = com.apple.eloquence.zh-TW.Grandpa, Name = Grandpa (Chinese (Taiwan))
# Voice 76: ID = com.apple.speech.synthesis.voice.Hysterical, Name = Jester
# Voice 77: ID = com.apple.voice.compact.ro-RO.Ioana, Name = Ioana
# Voice 78: ID = com.apple.eloquence.fr-FR.Jacques, Name = Jacques
# Voice 79: ID = com.apple.voice.compact.pt-PT.Joana, Name = Joana
# Voice 80: ID = com.apple.speech.synthesis.voice.Junior, Name = Junior
# Voice 81: ID = com.apple.voice.compact.th-TH.Kanya, Name = Kanya
# Voice 82: ID = com.apple.voice.compact.en-AU.Karen, Name = Karen
# Voice 83: ID = com.apple.speech.synthesis.voice.Kathy, Name = Kathy
# Voice 84: ID = com.apple.voice.compact.ja-JP.Kyoko, Name = Kyoko
# Voice 85: ID = com.apple.voice.compact.hr-HR.Lana, Name = Lana
# Voice 86: ID = com.apple.voice.compact.sk-SK.Laura, Name = Laura
# Voice 87: ID = com.apple.voice.compact.hi-IN.Lekha, Name = Lekha
# Voice 88: ID = com.apple.voice.compact.uk-UA.Lesya, Name = Lesya
# Voice 89: ID = com.apple.voice.compact.vi-VN.Linh, Name = Linh
# Voice 90: ID = com.apple.voice.compact.pt-BR.Luciana, Name = Luciana
# Voice 91: ID = com.apple.voice.compact.ar-001.Maged, Name = Majed
# Voice 92: ID = com.apple.voice.compact.hu-HU.Mariska, Name = Tünde
# Voice 93: ID = com.apple.voice.compact.zh-TW.Meijia, Name = Meijia
# Voice 94: ID = com.apple.voice.compact.el-GR.Melina, Name = Melina
# Voice 95: ID = com.apple.voice.compact.ru-RU.Milena, Name = Milena
# Voice 96: ID = com.apple.voice.compact.en-IE.Moira, Name = Moira
# Voice 97: ID = com.apple.voice.compact.es-ES.Monica, Name = Mónica
# Voice 98: ID = com.apple.voice.compact.ca-ES.Montserrat, Name = Montse
# Voice 99: ID = com.apple.voice.compact.nb-NO.Nora, Name = Nora
# Voice 100: ID = com.apple.speech.synthesis.voice.Organ, Name = Organ
# Voice 101: ID = com.apple.voice.compact.es-MX.Paulina, Name = Paulina
# Voice 102: ID = com.apple.speech.synthesis.voice.Princess, Name = Superstar
# Voice 103: ID = com.apple.speech.synthesis.voice.Ralph, Name = Ralph
# Voice 104: ID = com.apple.eloquence.de-DE.Reed, Name = Reed (German (Germany))
# Voice 105: ID = com.apple.eloquence.en-GB.Reed, Name = Reed (English (UK))
# Voice 106: ID = com.apple.eloquence.en-US.Reed, Name = Reed (English (US))
# Voice 107: ID = com.apple.eloquence.es-ES.Reed, Name = Reed (Spanish (Spain))
# Voice 108: ID = com.apple.eloquence.es-MX.Reed, Name = Reed (Spanish (Mexico))
# Voice 109: ID = com.apple.eloquence.fi-FI.Reed, Name = Reed (Finnish (Finland))
# Voice 110: ID = com.apple.eloquence.fr-CA.Reed, Name = Reed (French (Canada))
# Voice 111: ID = com.apple.eloquence.it-IT.Reed, Name = Reed (Italian (Italy))
# Voice 112: ID = com.apple.eloquence.ja-JP.Reed, Name = Reed (Japanese (Japan))
# Voice 113: ID = com.apple.eloquence.ko-KR.Reed, Name = Reed (Korean (South Korea))
# Voice 114: ID = com.apple.eloquence.pt-BR.Reed, Name = Reed (Portuguese (Brazil))
# Voice 115: ID = com.apple.eloquence.zh-CN.Reed, Name = Reed (Chinese (China mainland))
# Voice 116: ID = com.apple.eloquence.zh-TW.Reed, Name = Reed (Chinese (Taiwan))
# Voice 117: ID = com.apple.voice.compact.en-IN.Rishi, Name = Rishi
# Voice 118: ID = com.apple.eloquence.de-DE.Rocko, Name = Rocko (German (Germany))
# Voice 119: ID = com.apple.eloquence.en-GB.Rocko, Name = Rocko (English (UK))
# Voice 120: ID = com.apple.eloquence.en-US.Rocko, Name = Rocko (English (US))
# Voice 121: ID = com.apple.eloquence.es-ES.Rocko, Name = Rocko (Spanish (Spain))
# Voice 122: ID = com.apple.eloquence.es-MX.Rocko, Name = Rocko (Spanish (Mexico))
# Voice 123: ID = com.apple.eloquence.fi-FI.Rocko, Name = Rocko (Finnish (Finland))
# Voice 124: ID = com.apple.eloquence.fr-CA.Rocko, Name = Rocko (French (Canada))
# Voice 125: ID = com.apple.eloquence.fr-FR.Rocko, Name = Rocko (French (France))
# Voice 126: ID = com.apple.eloquence.it-IT.Rocko, Name = Rocko (Italian (Italy))
# Voice 127: ID = com.apple.eloquence.ja-JP.Rocko, Name = Rocko (Japanese (Japan))
# Voice 128: ID = com.apple.eloquence.ko-KR.Rocko, Name = Rocko (Korean (South Korea))
# Voice 129: ID = com.apple.eloquence.pt-BR.Rocko, Name = Rocko (Portuguese (Brazil))
# Voice 130: ID = com.apple.eloquence.zh-CN.Rocko, Name = Rocko (Chinese (China mainland))
# Voice 131: ID = com.apple.eloquence.zh-TW.Rocko, Name = Rocko (Chinese (Taiwan))
# Voice 132: ID = com.apple.voice.compact.en-US.Samantha, Name = Samantha
# Voice 133: ID = com.apple.eloquence.de-DE.Sandy, Name = Sandy (German (Germany))
# Voice 134: ID = com.apple.eloquence.en-GB.Sandy, Name = Sandy (English (UK))
# Voice 135: ID = com.apple.eloquence.en-US.Sandy, Name = Sandy (English (US))
# Voice 136: ID = com.apple.eloquence.es-ES.Sandy, Name = Sandy (Spanish (Spain))
# Voice 137: ID = com.apple.eloquence.es-MX.Sandy, Name = Sandy (Spanish (Mexico))
# Voice 138: ID = com.apple.eloquence.fi-FI.Sandy, Name = Sandy (Finnish (Finland))
# Voice 139: ID = com.apple.eloquence.fr-CA.Sandy, Name = Sandy (French (Canada))
# Voice 140: ID = com.apple.eloquence.fr-FR.Sandy, Name = Sandy (French (France))
# Voice 141: ID = com.apple.eloquence.it-IT.Sandy, Name = Sandy (Italian (Italy))
# Voice 142: ID = com.apple.eloquence.ja-JP.Sandy, Name = Sandy (Japanese (Japan))
# Voice 143: ID = com.apple.eloquence.ko-KR.Sandy, Name = Sandy (Korean (South Korea))
# Voice 144: ID = com.apple.eloquence.pt-BR.Sandy, Name = Sandy (Portuguese (Brazil))
# Voice 145: ID = com.apple.eloquence.zh-CN.Sandy, Name = Sandy (Chinese (China mainland))
# Voice 146: ID = com.apple.eloquence.zh-TW.Sandy, Name = Sandy (Chinese (Taiwan))
# Voice 147: ID = com.apple.voice.compact.da-DK.Sara, Name = Sara
# Voice 148: ID = com.apple.voice.compact.fi-FI.Satu, Name = Satu
# Voice 149: ID = com.apple.eloquence.de-DE.Shelley, Name = Shelley (German (Germany))
# Voice 150: ID = com.apple.eloquence.en-GB.Shelley, Name = Shelley (English (UK))
# Voice 151: ID = com.apple.eloquence.en-US.Shelley, Name = Shelley (English (US))
# Voice 152: ID = com.apple.eloquence.es-ES.Shelley, Name = Shelley (Spanish (Spain))
# Voice 153: ID = com.apple.eloquence.es-MX.Shelley, Name = Shelley (Spanish (Mexico))
# Voice 154: ID = com.apple.eloquence.fi-FI.Shelley, Name = Shelley (Finnish (Finland))
# Voice 155: ID = com.apple.eloquence.fr-CA.Shelley, Name = Shelley (French (Canada))
# Voice 156: ID = com.apple.eloquence.fr-FR.Shelley, Name = Shelley (French (France))
# Voice 157: ID = com.apple.eloquence.it-IT.Shelley, Name = Shelley (Italian (Italy))
# Voice 158: ID = com.apple.eloquence.ja-JP.Shelley, Name = Shelley (Japanese (Japan))
# Voice 159: ID = com.apple.eloquence.ko-KR.Shelley, Name = Shelley (Korean (South Korea))
# Voice 160: ID = com.apple.eloquence.pt-BR.Shelley, Name = Shelley (Portuguese (Brazil))
# Voice 161: ID = com.apple.eloquence.zh-CN.Shelley, Name = Shelley (Chinese (China mainland))
# Voice 162: ID = com.apple.eloquence.zh-TW.Shelley, Name = Shelley (Chinese (Taiwan))
# Voice 163: ID = com.apple.voice.compact.zh-HK.Sinji, Name = Sinji
# Voice 164: ID = com.apple.voice.compact.en-ZA.Tessa, Name = Tessa
# Voice 165: ID = com.apple.voice.compact.fr-FR.Thomas, Name = Thomas
# Voice 166: ID = com.apple.voice.compact.sl-SI.Tina, Name = Tina
# Voice 167: ID = com.apple.voice.compact.zh-CN.Tingting, Name = Tingting
# Voice 168: ID = com.apple.speech.synthesis.voice.Trinoids, Name = Trinoids
# Voice 169: ID = com.apple.speech.synthesis.voice.Whisper, Name = Whisper
# Voice 170: ID = com.apple.voice.compact.nl-NL.Xander, Name = Xander
# Voice 171: ID = com.apple.voice.compact.tr-TR.Yelda, Name = Yelda
# Voice 172: ID = com.apple.voice.compact.ko-KR.Yuna, Name = Yuna
# Voice 173: ID = com.apple.speech.synthesis.voice.Zarvox, Name = Zarvox
# Voice 174: ID = com.apple.voice.compact.pl-PL.Zosia, Name = Zosia
# Voice 175: ID = com.apple.voice.compact.cs-CZ.Zuzana, Name = Zuzana
# I0000 00:00:1729627204.382939  242196 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# I0000 00:00:1729627204.386301  242196 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# W0000 00:00:1729627204.388792  255359 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1729627204.449800  255352 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1729627204.455877  255352 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1729627204.456587  255354 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1729627204.457109  255355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1729627204.457116  255350 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1729627204.458852  255354 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1729627204.461473  255355 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1729627204.462876  255350 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
